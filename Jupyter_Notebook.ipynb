# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mostafa Hafez__
# <br> Data Analyst

# %% [markdown]
# *I am interested in studying data analysis because data is the basis of our world. Currently all our technologies produce a missive amount of data that could be sorted and analyzed to predict better solutions to our problems.*

# %% [markdown]
# ### This code is supposed to print the sum of 1 + 2

# %%
print(1+2)
# Out:
# 3

# %% [markdown]
# ***
# The result equals 3
# ***
#
# <a href="https://www.youtube.com/watch?v=QKMUdSLauaQ&list=PL8n3QglmB3idjo1vAYOVoo6-xiXO_U-4q" target="_blank">
#
# 1. Matwhashneesh
# 2. Costarica
# 3. Nefsy Ahbek
# 4. Roberto
# 5. Roma
# 6. Basrah w Atooh
# 7. Ana Negm
